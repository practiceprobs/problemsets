# %% [markdown]
# [![PracticeProbs](https://d33wubrfki0l68.cloudfront.net/b6800cc830e3fd5a3a4c3d9cfb1137e6a4c15c77/ec467/assets/images/transparent-1.png)](https://www.practiceprobs.com/)

# %% [markdown]
# # [The Simpsons](https://www.practiceprobs.com/problemsets/regular-expressions-in-python/beginner/the-simpsons/)
#
# Here's a quote from [The Simpsons](https://en.wikipedia.org/wiki/The_Simpsons).

# %%
quote = "Me Fail   English?\nThat's\tUnpossible."

# %% [markdown]
# Fix the errant spaces in the string.
#
# **Expected Result**

# %%
newquote = "Me Fail English? That's Unpossible."

# %% [markdown]
# Note that `\n` is a newline character and `\t` is a tab character. These become evident when you `print()` them.
#
# ```
# >>> print(quote)
# Me Fail   English?
# That's  Unpossible.
# ```

# %% [markdown]
# ---

# %%
# Your brilliant solution here!

# %% [markdown]
# ## [See our solution!](https://www.practiceprobs.com/problemsets/regular-expressions-in-python/beginner/the-simpsons/solution/)
