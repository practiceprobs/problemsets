# %% [markdown]
# [![PracticeProbs](https://d33wubrfki0l68.cloudfront.net/b6800cc830e3fd5a3a4c3d9cfb1137e6a4c15c77/ec467/assets/images/transparent-1.png)](https://www.practiceprobs.com/)

# %% [markdown]
# # [Product Volumes](https://www.practiceprobs.com/problemsets/python-pandas/advanced/product-volumes/)
#
# Given a Series of product `descriptions` like “birch table measures 3’x6’x2'”, estimate the volume of each product. (**Note**: 3' means 3 "feet" in the [imperial system of units](https://en.wikipedia.org/wiki/Imperial_units).)

# %%
import numpy as np
import pandas as pd

descriptions = pd.Series([
    "soft and fuzzy teddy bear, product dims: 1'x2'x1', shipping not included",
    "birch table measures 3'x6'x2'",
    "tortilla blanket ~ sleep like a fajita ~ 6'x8'x1'",
    "inflatable arm tube man | 12'x1'x1' when inflated",
    "dinosaur costume -- 6'x4'x2' -- for kids and small adults"
], dtype='string')

# %% [markdown]
# ---

# %%
# Your brilliant solution here!

# %% [markdown]
# ## [See our solution!](https://www.practiceprobs.com/problemsets/python-pandas/advanced/product-volumes/solution/)
