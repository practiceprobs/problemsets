# %% [markdown]
# [![PracticeProbs](https://d33wubrfki0l68.cloudfront.net/b6800cc830e3fd5a3a4c3d9cfb1137e6a4c15c77/ec467/assets/images/transparent-1.png)](https://www.practiceprobs.com/)

# %% [markdown]
# # [Iron Man](https://www.practiceprobs.com/problemsets/regular-expressions-in-python/advanced/iron-man/)
#
# Here's a quote from [Iron Man](https://en.wikipedia.org/wiki/Iron_Man_(2008_film)).

# %%
quote = "i told you, I don’t want to join your super secret boy band."

# %% [markdown]
# Find consecutive pairs of characters such that
#
# - each character is a letter in the phrase "iron man" (excluding the space)
# - overlapping pairs are allowed.
#
# **Expected Result**

# %%
charpairs = [
    'on', # ...I don’t want...
    'an', # ...don’t want to...
    'oi', # ...to join your...
    'in', # ...to join your...
    'an'  # ...boy band.
]

# %% [markdown]
# ---

# %%
# Your brilliant solution here!

# %% [markdown]
# ## [See our solution!](https://www.practiceprobs.com/problemsets/regular-expressions-in-python/advanced/iron-man/solution/)
